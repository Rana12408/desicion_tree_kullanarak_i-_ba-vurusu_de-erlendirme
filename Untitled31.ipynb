# %%
import numpy as np
import pandas as pd
from sklearn import tree
df=pd.read_csv("/content/DecisionTreesClassificationDataSet (1).csv")
df.head()
# Out:
#    Deneyim Yili SuanCalisiyor?  Eski Calistigi Firmalar Egitim Seviyesi  \
# 0            11              Y                        4              BS
# 1             0              N                        0             PhD
# 2             5              Y                        2              MS
# 3             3              N                        1              BS
# 4             0              N                        0              BS
#
#   Top10 Universite? StajBizdeYaptimi? IseAlindi
# 0                 N                 N         Y
# 1                 Y                 Y         Y
# 2                 N                 Y         Y
# 3                 N                 Y         Y
# 4                 N                 N         N

# %%
import numpy as np
import pandas as pd
from sklearn import tree

df = pd.read_csv("/content/DecisionTreesClassificationDataSet (1).csv")

# Sözlükler
duzeltme_mapping = {"Y": 1, "N": 0}
duzeltme_mapping_egitim = {"BS": 0, "MS": 1, "PhD": 2}

# Sütun adlarını düzelt
df.rename(columns={
    "Top10 Universite?": "Top10Universite",
    "Egitim Seviyesi": "Egitim_Seviyesi"
}, inplace=True)

# Kategorik sütunları sayısal değerlere dönüştür
df["SuanCalisiyor?"] = df["SuanCalisiyor?"].map(duzeltme_mapping)
df["StajBizdeYaptimi?"] = df["StajBizdeYaptimi?"].map(duzeltme_mapping)
df["IseAlindi"] = df["IseAlindi"].map(duzeltme_mapping)
df["Top10Universite"] = df["Top10Universite"].map(duzeltme_mapping)
df["Egitim_Seviyesi"] = df["Egitim_Seviyesi"].map(duzeltme_mapping_egitim)

# Kontrol
df.head()
# Out:
#    Deneyim Yili  SuanCalisiyor?  Eski Calistigi Firmalar  Egitim_Seviyesi  \
# 0            11               1                        4                0
# 1             0               0                        0                2
# 2             5               1                        2                1
# 3             3               0                        1                0
# 4             0               0                        0                0
#
#    Top10Universite  StajBizdeYaptimi?  IseAlindi
# 0                0                  0          1
# 1                1                  1          1
# 2                0                  1          1
# 3                0                  1          1
# 4                0                  0          0

# %%
y=df["IseAlindi"]
x=df.drop(["IseAlindi"],axis=1)

# %%
clf=tree.DecisionTreeClassifier()
clf=clf.fit(x,y)

# %%
clf.predict([[5,1,3,0,0,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
